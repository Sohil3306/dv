# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
def tokenize_text(text):
    sentences = sent_tokenize(text)
    words = [word_tokenize(sentence) for sentence in sentences]
    paragraphs = text.split("\n\n")
    return sentences, words, paragraphs                                                            
text = input("Enter text for tokenization:\n")
sentences, words, paragraphs = tokenize_text(text)
print("\nSentences:", sentences)
print("\nWords:", words)
print("\nParagraphs:", paragraphs)
# Out:
# Enter text for tokenization:
#  Don't let someone else's opinion of you become your reality
# Sentences: ["Don't let someone else's opinion of you become your reality"]
#
# Words: [['Do', "n't", 'let', 'someone', 'else', "'s", 'opinion', 'of', 'you', 'become', 'your', 'reality']]
#
# Paragraphs: ["Don't let someone else's opinion of you become your reality"]
